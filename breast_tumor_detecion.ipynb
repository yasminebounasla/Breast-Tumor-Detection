# %% [markdown]
# **Data Processing**

# %%
# import os
# from PIL import Image
# import numpy as np

# # Set parameters
# data_dir = './data/train/'  # Path to your train folder
# target_size = (224, 224)     # Target size for resizing (width, height)

# def process_images(folder_path):
#     # List all files in the given folder
#     for root, dirs, files in os.walk(folder_path):
#         for file in files:
#             if file.endswith(('.jpg')): 
#                 image_path = os.path.join(root, file)
                
#                 # Open and resize the image
#                 with Image.open(image_path) as img:
#                     img = img.resize(target_size)  # Resize image
                    
#                     # Normalize the image
#                     img_array = np.array(img) / 255.0  # Scale pixel values to [0, 1]

#                     # Optionally, save the processed image
#                     # Save path can be modified as needed
#                     processed_image_path = os.path.join(root, f'processed_{file}')
#                     Image.fromarray((img_array * 255).astype(np.uint8)).save(processed_image_path)

# # Process both Benign and Malignant images
# process_images(os.path.join(data_dir, '0')) 
# process_images(os.path.join(data_dir, '1'))  

# print("Image processing complete!")

# %%
# import os

# # Define paths to your benign (0) and malignant (1) image folders
# benign_dir = './data/train/0'
# malignant_dir = './data/train/1'

# # Count the number of images in each folder
# benign_count = len([file for file in os.listdir(benign_dir) if file.endswith(('.jpg', '.png', '.jpeg'))])
# malignant_count = len([file for file in os.listdir(malignant_dir) if file.endswith(('.jpg', '.png', '.jpeg'))])

# # Print the counts
# print(f'Number of benign images: {benign_count}')
# print(f'Number of malignant images: {malignant_count}')

# %%
# import os
# import cv2
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from imblearn.over_sampling import RandomOverSampler

# # Set the base directory where your images are stored
# base_dir = './data/train/'

# # Initialize lists to hold image paths and labels
# image_paths = []
# labels = []

# # Loop through benign and malignant folders
# for label in ['0', '1']:  # '0' for benign, '1' for malignant
#     folder_path = os.path.join(base_dir, label)
#     for file in os.listdir(folder_path):
#         if file.endswith(('.jpg', '.png', '.jpeg')):
#             image_paths.append(os.path.join(folder_path, file))  # Full image path
#             labels.append(int(label))  # Corresponding label

# %%
# # Convert lists to NumPy arrays for further processing
# image_paths = np.array(image_paths)
# labels = np.array(labels)

# # Combine image paths and labels into a DataFrame
# data = pd.DataFrame({'file_path': image_paths, 'label': labels})

# # Split the dataset into training and testing sets (80% train, 20% test)
# X_train, X_test, y_train, y_test = train_test_split(data['file_path'], data['label'], test_size=0.2, random_state=42)

# # Oversampling
# ros = RandomOverSampler(random_state=42)
# X_train_resampled, y_train_resampled = ros.fit_resample(X_train.values.reshape(-1, 1), y_train)


# # Convert resampled data back to arrays
# X_train_resampled = np.array([path[0] for path in X_train_resampled])

# %%
# import numpy as np
# from PIL import Image

# def load_image(image_path):
#     img = Image.open(image_path)  # Load image
#     img_array = np.array(img) / 255.0  # Normalize pixel values
#     return img_array

# def load_images_in_batches(image_paths, batch_size=32):
#     for i in range(0, len(image_paths), batch_size):
#         batch_paths = image_paths[i:i + batch_size]
#         batch_images = [load_image(path) for path in batch_paths]
#         yield np.array(batch_images)  # Return the batch as a NumPy array

# %%
# import tensorflow as tf
# from tensorflow.keras import layers, models

# def create_cnn_model():
#     model = models.Sequential()
#     model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
#     model.add(layers.MaxPooling2D((2, 2)))
#     model.add(layers.Conv2D(64, (3, 3), activation='relu'))
#     model.add(layers.MaxPooling2D((2, 2)))
#     model.add(layers.Conv2D(128, (3, 3), activation='relu'))
#     model.add(layers.MaxPooling2D((2, 2)))
#     model.add(layers.Flatten())
#     model.add(layers.Dense(128, activation='relu'))
#     model.add(layers.Dense(1, activation='sigmoid'))  # Change to 'softmax' for multiple classes
#     return model

# %%
# model = create_cnn_model()
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# # Evaluate the model on the test dataset
# test_loss, test_accuracy = model.evaluate(X_test_processed, y_test, verbose=1)

# print(f'Test Loss: {test_loss:.4f}')
# print(f'Test Accuracy: {test_accuracy:.4f}')

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf
from tensorflow.keras import layers, models

# Set parameters
data_dir = './data/train/'  # Path to your train folder
target_size = (224, 224)     # Target size for resizing (width, height)

# Function to process images
def process_images(folder_path):
    processed_images = []  # To hold paths of processed images
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(('.jpg')):
                image_path = os.path.join(root, file)
                try:
                    with Image.open(image_path) as img:
                        img = img.resize(target_size)  # Resize image
                        img_array = np.array(img) / 255.0  # Normalize pixel values
                        processed_image_path = os.path.join(root, f'processed_{file}')
                        Image.fromarray((img_array * 255).astype(np.uint8)).save(processed_image_path)
                        processed_images.append(processed_image_path)  # Add processed image path
                except Exception as e:
                    print(f"Error processing image {image_path}: {e}")
    return processed_images  # Return processed image paths

# %%
# Process both Benign and Malignant images
benign_images = process_images(os.path.join(data_dir, '0')) 
malignant_images = process_images(os.path.join(data_dir, '1'))

# %%
# Initialize lists to hold image paths and labels
image_paths = benign_images + malignant_images
labels = [0] * len(benign_images) + [1] * len(malignant_images)  # 0 for benign, 1 for malignant

# Convert lists to NumPy arrays
image_paths = np.array(image_paths)
labels = np.array(labels)

# %%
# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=0.2, random_state=42)

# Oversampling
ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train.reshape(-1, 1), y_train)

# Convert resampled data back to arrays
X_train_resampled = np.array([path[0] for path in X_train_resampled])

# %%
# Function to load and preprocess images
def load_image(image_path):
    try:
        img = Image.open(image_path)  # Load image
        img = img.resize(target_size)  # Ensure image is resized
        img_array = np.array(img) / 255.0  # Normalize pixel values
        return img_array
    except Exception as e:
        print(f"Error loading image {image_path}: {e}")
        return None

# Function to load images in batches
def load_images_in_batches(image_paths, batch_size=32):
    for i in range(0, len(image_paths), batch_size):
        batch_paths = image_paths[i:i + batch_size]
        batch_images = []
        for path in batch_paths:
            img = load_image(path)
            if img is not None:  # Ensure that the image is loaded successfully
                batch_images.append(img)
        yield np.array(batch_images)  # Return the batch as a NumPy array

# %%
# Create CNN model
def create_cnn_model():
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))  # Binary classification
    return model

# Create and compile model
model = create_cnn_model()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\Bounasla Yasmine\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Training with batches
epochs = 2  # Adjust as needed
batch_size = 128

for epoch in range(epochs):
    for X_train_batch in load_images_in_batches(X_train_resampled, batch_size):
        # Create corresponding labels for the current batch
        y_train_batch = y_train_resampled[len(X_train_batch) * epoch: len(X_train_batch) * (epoch + 1)]
        
        # Train your model on the current batch
        model.fit(X_train_batch, y_train_batch, epochs=1, verbose=1)  # Adjust epochs as needed

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.5688 - loss: 0.9755
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6708 - loss: 0.6469
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7365 - loss: 0.6140
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7208 - loss: 0.6146
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.6073
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7292 - loss: 0.5934
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7563 - loss: 0.5593
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6833 - loss: 0.6381
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6979 - loss: 0.6093
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.5996
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7104 - loss: 0.6377
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7375 - loss: 0.5849
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7771 - loss: 0.5621
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7219 - loss: 0.5972
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7177 - loss: 0.5926
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7333 - loss: 0.5821
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7500 - loss: 0.5582
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7042 - loss: 0.6132
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7344 - loss: 0.5768
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.6026
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7167 - loss: 0.5958
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7385 - loss: 0.5798
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7385 - loss: 0.5880
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7375 - loss: 0.5795
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7104 - loss: 0.6089
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7260 - loss: 0.5918
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7229 - loss: 0.5931
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6969 - loss: 0.6154
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6875 - loss: 0.6252
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7354 - loss: 0.5969
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7510 - loss: 0.5650
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7208 - loss: 0.5890
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6844 - loss: 0.6318
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7677 - loss: 0.5524
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7146 - loss: 0.6032
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7563 - loss: 0.5549
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7240 - loss: 0.6030
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7323 - loss: 0.5821
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6990 - loss: 0.6234
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7177 - loss: 0.5985
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7219 - loss: 0.5922
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5770
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7177 - loss: 0.6040
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7281 - loss: 0.5846
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7271 - loss: 0.5862
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7208 - loss: 0.5951
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7323 - loss: 0.5870
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6979 - loss: 0.6114
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7229 - loss: 0.5942
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6938 - loss: 0.6240
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.5989
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7156 - loss: 0.5964
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6510 - loss: 0.6645
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6729 - loss: 0.6359
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6938 - loss: 0.6186
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7354 - loss: 0.5765
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6802 - loss: 0.6392
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7240 - loss: 0.5912
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7385 - loss: 0.5768
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6958 - loss: 0.6207
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7000 - loss: 0.6065
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7156 - loss: 0.5962
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7146 - loss: 0.5962
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7479 - loss: 0.5747
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7740 - loss: 0.5499
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7469 - loss: 0.5693
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7219 - loss: 0.5936
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7229 - loss: 0.5905
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7344 - loss: 0.5806
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7490 - loss: 0.5682
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7083 - loss: 0.6045
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7167 - loss: 0.5966
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7208 - loss: 0.5927
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6938 - loss: 0.6178
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7104 - loss: 0.6007
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6917 - loss: 0.6174
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6906 - loss: 0.6207
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5746
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7177 - loss: 0.6018
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7177 - loss: 0.5967
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7167 - loss: 0.5984
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7281 - loss: 0.5891
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7365 - loss: 0.5783
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7490 - loss: 0.5654
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6646 - loss: 0.6498
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6979 - loss: 0.6171
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7490 - loss: 0.5709
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7260 - loss: 0.5882
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7083 - loss: 0.6065
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7188 - loss: 0.5934
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7427 - loss: 0.5722
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7563 - loss: 0.5601
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5741
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7073 - loss: 0.6054
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7229 - loss: 0.5909
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7469 - loss: 0.5700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7094 - loss: 0.6035
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7281 - loss: 0.5864
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7229 - loss: 0.5893
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7073 - loss: 0.6051
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7458 - loss: 0.5691
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7344 - loss: 0.5792
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7073 - loss: 0.6050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7250 - loss: 0.5894
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7094 - loss: 0.6020
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7115 - loss: 0.6002
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7083 - loss: 0.6010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7146 - loss: 0.6025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6740 - loss: 0.6425
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7073 - loss: 0.6061
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7312 - loss: 0.5821
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7323 - loss: 0.5837
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7448 - loss: 0.5665
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7365 - loss: 0.5812
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7219 - loss: 0.5947
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7240 - loss: 0.5906
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7031 - loss: 0.6102
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6844 - loss: 0.6253
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7000 - loss: 0.6119
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7292 - loss: 0.5849
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7146 - loss: 0.5991
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7312 - loss: 0.5839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7177 - loss: 0.5949
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7271 - loss: 0.5869
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7312 - loss: 0.5833
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6833 - loss: 0.6282
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7010 - loss: 0.6104
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7333 - loss: 0.5812
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7250 - loss: 0.5883
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7396 - loss: 0.5743
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7333 - loss: 0.5801
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 0.7031 - loss: 0.6096
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step - accuracy: 0.6906 - loss: 0.6195
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 8s/step - accuracy: 0.7292 - loss: 0.5859
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step - accuracy: 0.7198 - loss: 0.5925
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.7375 - loss: 0.5773
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7740 - loss: 0.5364
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7458 - loss: 0.5682
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7312 - loss: 0.5822
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7021 - loss: 0.6097
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7188 - loss: 0.5942
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7698 - loss: 0.5482
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7344 - loss: 0.5819
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7604 - loss: 0.5499
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5737
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5743
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.5996
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7354 - loss: 0.5794
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7437 - loss: 0.5696
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7073 - loss: 0.6079
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7542 - loss: 0.5598
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.7115 - loss: 0.6033
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 25s 6s/step - accuracy: 0.7063 - loss: 0.6092
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.7312 - loss: 0.5816
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7292 - loss: 0.5841
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6958 - loss: 0.6195
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7250 - loss: 0.5878
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7615 - loss: 0.5521
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7406 - loss: 0.5721
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7385 - loss: 0.5742
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7115 - loss: 0.6040
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7021 - loss: 0.6102
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7604 - loss: 0.5555
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7510 - loss: 0.5612
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7427 - loss: 0.5706
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7802 - loss: 0.5332
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7531 - loss: 0.5587
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7042 - loss: 0.6116
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7219 - loss: 0.5913
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7354 - loss: 0.5776
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7417 - loss: 0.5721
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7365 - loss: 0.5781
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7448 - loss: 0.5688
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7312 - loss: 0.5824
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7437 - loss: 0.5691
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7375 - loss: 0.5749
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7625 - loss: 0.5506
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7552 - loss: 0.5567
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7469 - loss: 0.5658
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.7698 - loss: 0.5433
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.7271 - loss: 0.5859
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7146 - loss: 0.5999
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7021 - loss: 0.6089
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7604 - loss: 0.5528
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7094 - loss: 0.6081
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7292 - loss: 0.5853
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7188 - loss: 0.5960
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7583 - loss: 0.5561
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7292 - loss: 0.5834
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7271 - loss: 0.5862
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7312 - loss: 0.5812
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7365 - loss: 0.5746
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7417 - loss: 0.5720
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7031 - loss: 0.6095
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7208 - loss: 0.5929
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7302 - loss: 0.5823
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7437 - loss: 0.5718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7365 - loss: 0.5733
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.6068
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7427 - loss: 0.5727
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7198 - loss: 0.5907
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7750 - loss: 0.5424
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7042 - loss: 0.6140
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7417 - loss: 0.5718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.5989
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6979 - loss: 0.6153
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7333 - loss: 0.5788
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7333 - loss: 0.5821
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5767
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7292 - loss: 0.5863
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7833 - loss: 0.5311
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7646 - loss: 0.5480
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7563 - loss: 0.5569
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7312 - loss: 0.5817
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7563 - loss: 0.5598
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5743
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7104 - loss: 0.6039
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7490 - loss: 0.5654
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7875 - loss: 0.5260
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7521 - loss: 0.5599
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7229 - loss: 0.5919
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7531 - loss: 0.5613
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7448 - loss: 0.5692
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7802 - loss: 0.5344
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7771 - loss: 0.5349
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7542 - loss: 0.5583
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7271 - loss: 0.5870
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7292 - loss: 0.5848
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7406 - loss: 0.5724
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7094 - loss: 0.6038
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6979 - loss: 0.6155
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7500 - loss: 0.5638
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7479 - loss: 0.5657
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7490 - loss: 0.5644
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5733
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7625 - loss: 0.5529
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7198 - loss: 0.5944
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7208 - loss: 0.5929
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7021 - loss: 0.6112
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7135 - loss: 0.5986
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7437 - loss: 0.5692
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7240 - loss: 0.5914
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7000 - loss: 0.6164
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7406 - loss: 0.5733
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7750 - loss: 0.5385
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7219 - loss: 0.5923
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1000ms/step - accuracy: 0.6979 - loss: 0.6164
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7229 - loss: 0.5904
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7188 - loss: 0.5950
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7333 - loss: 0.5798
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7927 - loss: 0.5208
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7354 - loss: 0.5787
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7167 - loss: 0.5973
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7708 - loss: 0.5458
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7115 - loss: 0.6022
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7563 - loss: 0.5589
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6865 - loss: 0.6294
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7396 - loss: 0.5741
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7708 - loss: 0.5423
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7698 - loss: 0.5409
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7708 - loss: 0.5398
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7354 - loss: 0.5777
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7552 - loss: 0.5601
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7344 - loss: 0.5798
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7094 - loss: 0.6029
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7563 - loss: 0.5581
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7635 - loss: 0.5487
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 941ms/step - accuracy: 0.6958 - loss: 0.6219
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 14
#      11         model.fit(X_train_batch, y_train_batch, epochs=1, verbose=1)  # Adjust epochs as needed
#      13 # Evaluate the model on the test dataset
# ---> 14 test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
#      15 print(f'Test Loss: {test_loss:.4f}')
#      16 print(f'Test Accuracy: {test_accuracy:.4f}')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python39\site-packages\optree\ops.py:594, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     592 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     593 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 594 return treespec.unflatten(map(func, *flat_args))
#
# ValueError: Invalid dtype: str4608

# %%
def load_test_images(test_paths):
    return np.array([load_image(path) for path in test_paths if load_image(path) is not None])

X_test_processed = load_test_images(X_test)  # Load images from paths in X_test

# %%
y_test = np.array(y_test).astype(np.float32)  # Convert to a float array if necessary

# %%
print(X_test_processed.shape)  # Should be (number_of_samples, 224, 224, 3)
print(y_test.shape)  # Should be (number_of_samples,)
# Out:
# (2940, 224, 224, 3)
# (2940,)

# %%
# Load and preprocess test images
X_test_processed = load_test_images(X_test)  # Ensure this function is defined as above

# Ensure y_test is a NumPy array and has the correct dtype
y_test = np.array(y_test).astype(np.float32)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_processed, y_test, verbose=1)

print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 174ms/step - accuracy: 0.7131 - loss: 0.6016
# Test Loss: 0.5856
# Test Accuracy: 0.7282

# %%
import numpy as np
from PIL import Image

def predict_tumor(image_path, model):
    # Load the image
    img = Image.open(image_path)
    
    # Ensure the image is in the correct size and format
    img = img.resize((224, 224))  # Resize if necessary for your model
    img_array = np.array(img) / 255.0  # Normalize pixel values
    
    # Expand dimensions to match the model input shape
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    
    # Make prediction
    prediction = model.predict(img_array)
    
    # Interpret the prediction
    return "Malignant" if prediction[0] > 0.5 else "Benign"

# %%
# Example usage
image_path = './data/test/25_1723979573_png.rf.cb7b0577d1de86f18474daa325bdd714.jpg'  # Replace with the path to your test image
result = predict_tumor(image_path, model)
print(f'The tumor is: {result}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# The tumor is: Benign
